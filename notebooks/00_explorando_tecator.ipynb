# %%
import matplotlib.pyplot as plt

y = dados.target[:, 0]   # agora sim: gordura

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

for i in range(20):
    ax1.plot(eixo, X[i], linewidth=0.9)
ax1.set_xlabel("comprimento de onda (nm)")
ax1.set_ylabel("absorbância")
ax1.set_title("20 espectros do Tecator")

ax2.hist(y, bins=25, edgecolor="black")
ax2.set_xlabel("gordura (%)")
ax2.set_ylabel("nº de amostras")
ax2.set_title("distribuição do alvo")

plt.tight_layout()
plt.show()
